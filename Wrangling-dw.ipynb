# %%
# %logstop
# %logstart -rtq ~/.logs/dw.py append
# %matplotlib inline
import matplotlib
import seaborn as sns
sns.set()
matplotlib.rcParams['figure.dpi'] = 144

# %%
from static_grader import grader

# %% [markdown]
# # DW Miniproject
# ## Introduction
#
# The objective of this miniproject is to exercise your ability to wrangle tabular data set and aggregate large data sets into meaningful summary statistics. We'll work with the same medical data used in the `pw` miniproject but leverage the power of Pandas to more efficiently represent and act on our data.

# %% [markdown]
# ## Downloading the data
#
# We first need to download the data we'll be using from Amazon S3:

# %%
# !mkdir dw-data
# !wget http://dataincubator-wqu.s3.amazonaws.com/dwdata/201701scripts_sample.csv.gz -nc -P ./dw-data/
# !wget http://dataincubator-wqu.s3.amazonaws.com/dwdata/201606scripts_sample.csv.gz -nc -P ./dw-data/
# !wget http://dataincubator-wqu.s3.amazonaws.com/dwdata/practices.csv.gz -nc -P ./dw-data/
# !wget http://dataincubator-wqu.s3.amazonaws.com/dwdata/chem.csv.gz -nc -P ./dw-data/
# Out:
# --2020-08-18 23:00:49--  http://dataincubator-wqu.s3.amazonaws.com/dwdata/201701scripts_sample.csv.gz
# Resolving dataincubator-wqu.s3.amazonaws.com (dataincubator-wqu.s3.amazonaws.com)... 52.217.40.124
# Connecting to dataincubator-wqu.s3.amazonaws.com (dataincubator-wqu.s3.amazonaws.com)|52.217.40.124|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19011654 (18M) [text/csv]
# Saving to: ‘./dw-data/201701scripts_sample.csv.gz’
#
# 201701scripts_sampl 100%[===================>]  18.13M  51.8MB/s    in 0.3s
#
# 2020-08-18 23:00:49 (51.8 MB/s) - ‘./dw-data/201701scripts_sample.csv.gz’ saved [19011654/19011654]
#
# --2020-08-18 23:00:49--  http://dataincubator-wqu.s3.amazonaws.com/dwdata/201606scripts_sample.csv.gz
# Resolving dataincubator-wqu.s3.amazonaws.com (dataincubator-wqu.s3.amazonaws.com)... 52.216.113.219
# Connecting to dataincubator-wqu.s3.amazonaws.com (dataincubator-wqu.s3.amazonaws.com)|52.216.113.219|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18768259 (18M) [text/csv]
# Saving to: ‘./dw-data/201606scripts_sample.csv.gz’
#
# 201606scripts_sampl 100%[===================>]  17.90M  37.8MB/s    in 0.5s
#
# 2020-08-18 23:00:50 (37.8 MB/s) - ‘./dw-data/201606scripts_sample.csv.gz’ saved [18768259/18768259]
#
# --2020-08-18 23:00:50--  http://dataincubator-wqu.s3.amazonaws.com/dwdata/practices.csv.gz
# Resolving dataincubator-wqu.s3.amazonaws.com (dataincubator-wqu.s3.amazonaws.com)... 52.216.113.219
# Connecting to dataincubator-wqu.s3.amazonaws.com (dataincubator-wqu.s3.amazonaws.com)|52.216.113.219|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 333225 (325K) [application/x-gzip]
# Saving to: ‘./dw-data/practices.csv.gz’
#
# practices.csv.gz    100%[===================>] 325.42K  --.-KB/s    in 0.01s
#
# 2020-08-18 23:00:50 (29.9 MB/s) - ‘./dw-data/practices.csv.gz’ saved [333225/333225]
#
# --2020-08-18 23:00:51--  http://dataincubator-wqu.s3.amazonaws.com/dwdata/chem.csv.gz
# Resolving dataincubator-wqu.s3.amazonaws.com (dataincubator-wqu.s3.amazonaws.com)... 52.217.40.124
# Connecting to dataincubator-wqu.s3.amazonaws.com (dataincubator-wqu.s3.amazonaws.com)|52.217.40.124|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 31829 (31K) [application/x-gzip]
# Saving to: ‘./dw-data/chem.csv.gz’
#
# chem.csv.gz         100%[===================>]  31.08K  --.-KB/s    in 0s
#
# 2020-08-18 23:00:51 (64.0 MB/s) - ‘./dw-data/chem.csv.gz’ saved [31829/31829]

# %% [markdown]
# ## Loading the data
#
# Similar to the `PW` miniproject, the first step is to read in the data. The data files are stored as compressed CSV files. You can load the data into a Pandas DataFrame by making use of the `gzip` package to decompress the files and Panda's `read_csv` methods to parse the data into a DataFrame. You may want to check the Pandas documentation for parsing [CSV](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html) files for reference.
#
# For a description of the data set please, refer to the [PW miniproject](./pw.ipynb). **Note that all questions make use of the 2017 data only, except for Question 5 which makes use of both the 2017 and 2016 data.**

# %%
import pandas as pd
import numpy as np
import gzip

# %%
# load the 2017 data
scripts = pd.read_csv('dw-data/201701scripts_sample.csv.gz')
scripts.head()
# Out:
#   practice   bnf_code                              bnf_name  items   nic  \
# 0   N85639  0106020C0                 Bisacodyl_Tab E/C 5mg      1  0.39
# 1   N85639  0106040M0      Movicol Plain_Paed Pdr Sach 6.9g      1  4.38
# 2   N85639  0301011R0    Salbutamol_Inha 100mcg (200 D) CFF      1  1.50
# 3   N85639  0304010G0  Chlorphenamine Mal_Oral Soln 2mg/5ml      1  2.62
# 4   N85639  0401020K0                      Diazepam_Tab 2mg      1  0.16
#
#    act_cost  quantity
# 0      0.47        12
# 1      4.07        30
# 2      1.40         1
# 3      2.44       150
# 4      0.26         6

# %%
col_names=[ 'code', 'name', 'addr_1', 'addr_2', 'borough', 'village', 'post_code']
practices = pd.read_csv('dw-data/practices.csv.gz', names=col_names) #,names=col_names
practices.head()
# Out:
#      code                        name                   addr_1         addr_2  \
# 0  A81001         THE DENSHAM SURGERY        THE HEALTH CENTRE  LAWSON STREET
# 1  A81002  QUEENS PARK MEDICAL CENTRE  QUEENS PARK MEDICAL CTR  FARRER STREET
# 2  A81003   VICTORIA MEDICAL PRACTICE        THE HEALTH CENTRE  VICTORIA ROAD
# 3  A81004      WOODLANDS ROAD SURGERY         6 WOODLANDS ROAD            NaN
# 4  A81005          SPRINGWOOD SURGERY       SPRINGWOOD SURGERY   RECTORY LANE
#
#             borough    village post_code
# 0  STOCKTON ON TEES  CLEVELAND  TS18 1HU
# 1  STOCKTON ON TEES  CLEVELAND  TS18 2AW
# 2        HARTLEPOOL  CLEVELAND  TS26 8DB
# 3     MIDDLESBROUGH  CLEVELAND   TS1 3BE
# 4       GUISBOROUGH        NaN  TS14 7DJ

# %%
chem=pd.read_csv('dw-data/chem.csv.gz')
chem.head()
# Out:
#     CHEM SUB                                NAME
# 0  0101010A0                     Alexitol Sodium
# 1  0101010B0                          Almasilate
# 2  0101010C0                 Aluminium Hydroxide
# 3  0101010D0  Aluminium Hydroxide With Magnesium
# 4  0101010E0                        Hydrotalcite

# %% [markdown]
# Now that we've loaded in the data, let's first replicate our results from the `PW` miniproject. Note that we are now working with a larger data set so the answers will be different than in the `PW` miniproject even if the analysis is the same.

# %% [markdown]
# ## Question 1: summary_statistics
#
# In the `PW` miniproject we first calculated the total, mean, standard deviation, and quartile statistics of the `'items'`, `'quantity'`', `'nic'`, and `'act_cost'` fields. To do this we had to write some functions to calculate the statistics and apply the functions to our data structure. The DataFrame has a `describe` method that will calculate most (not all) of these things for us.
#
# Submit the summary statistics to the grader as a list of tuples: [('act_cost', (total, mean, std, q25, median, q75)), ...]

# %%
summary_stats=scripts.describe()

# %%
summary_stats
# Out:
#                items            nic       act_cost       quantity
# count  973193.000000  973193.000000  973193.000000  973193.000000
# mean        9.133136      73.058915      67.986613     741.329835
# std        29.204198     188.070257     174.401703    3665.426958
# min         1.000000       0.000000       0.040000       0.000000
# 25%         1.000000       7.800000       7.330000      28.000000
# 50%         2.000000      22.640000      21.220000     100.000000
# 75%         6.000000      65.000000      60.670000     350.000000
# max      2384.000000   16320.000000   15108.320000  577720.000000

# %%
total=scripts[['items', 'quantity', 'nic', 'act_cost']].sum()

# %%
type(total)
# Out:
# pandas.core.series.Series

# %%
total.index
# Out:
# Index(['items', 'quantity', 'nic', 'act_cost'], dtype='object')

# %%
total['quantity']
# Out:
# 721457006.0

# %%
from math import sqrt
def describe(key):
    NUM=len(scripts)

    total = sum([script[key] for script in scripts])
    avg = total/NUM
    
    s = sqrt(sum([(script[key] - avg) ** 2 for script in scripts]) / NUM)
    
    vals = sorted([script[key] for script in scripts])
     
    q25 = vals[NUM // 4]
    med = vals[NUM // 2]
    q75 = vals[-NUM // 4]

    return (total, avg, s, q25, med, q75)

# %%
def summary_key(key):
    
    NUM=len(scripts)
    total=scripts[key].sum()
    
    summary = scripts[key].describe() 
    
    avg= total/NUM 
    std = summary.loc['std'] 
    q25 = summary.loc['25%'] 
    med = summary.loc['50%'] 
    q75 = summary.loc['75%'] 
    return (total,avg,std,q25,med,q75)

# %%
summary_stats = [('items', summary_key('items')),
           ('quantity', summary_key('quantity')),
           ('nic', summary_key('nic')),
           ('act_cost', summary_key('act_cost'))]

# %%
summary_stats
# Out:
# [('items', (8888304, 9.133135976111625, 29.204198282803603, 1.0, 2.0, 6.0)),
#  ('quantity',
#   (721457006, 741.3298348837282, 3665.426958467915, 28.0, 100.0, 350.0)),
#  ('nic',
#   (71100424.84000002, 73.05891517920908, 188.070256906825, 7.8, 22.64, 65.0)),
#  ('act_cost',
#   (66164096.11999999,
#    67.98661326170655,
#    174.40170332301963,
#    7.33,
#    21.22,
#    60.67))]

# %%
summary_stats = [('items', (0,) * 6), ('quantity', (0,) * 6), ('nic', (0,) * 6), ('act_cost', (0,) * 6)]

# %%
grader.score.dw__summary_statistics(summary_stats)
# Out:
# ==================
# Your score:  1.0
# ==================

# %%
def stats(items):
    summary_stats=[]
    for item in items:
        
        N = len(scripts)
        total = scripts[key].sum()
        mean = total/N
        std_dn = scripts.loc[:,item].std()
        first_q= scripts.loc[:,item].sort_values(ascending=True)[(N+1)//4]
        median= scripts.loc[:,item].median()
        third_q= scripts.loc[:,item].sort_values(ascending=True)[(N+1)*3//4]

        summary_stats.append((item, (total, mean, std_dn, first_q, median, third_q)))

    return summary_stats

# %%
items = ['items', 'quantity', 'nic', 'act_cost']

# %%
summary_stats = stats(items)

# %% [markdown]
# ## Question 2: most_common_item
#
# We can also easily compute summary statistics on groups within the data. In the `pw` miniproject we had to explicitly construct the groups based on the values of a particular field. Pandas will handle that for us via the `groupby` method. This process is [detailed in the Pandas documentation](https://pandas.pydata.org/pandas-docs/stable/groupby.html).
#
# Use `groupby` to calculate the total number of items dispensed for each `'bnf_name'`. Find the item with the highest total and return the result as `[(bnf_name, total)]`.

# %%
total_bnf_name=scripts.groupby('bnf_name')['items'].sum()

# %%
total_bnf_name
# Out:
# bnf_name
# 365 Film 10cm x 12cm VP Adh Film Dress       2
# 365 Non Adherent 10cm x 10cm Pfa Plas Fa     3
# 365 Non Adherent 10cm x 20cm Pfa Plas Fa     1
# 365 Non Woven Island 8cm x 10cm Adh Dres     1
# 365 Transpt Island 5cm x 7.2cm VP Adh Fi     2
#                                             ..
# nSpire PiKo-1 Stnd Range Peak Flow Meter     1
# nSpire Pocket Peak Low Range Peak Flow M     4
# nSpire Pocket Peak Stnd Range Peak Flow      8
# oraNurse_Toothpaste Orig (1450ppm)           4
# palmdoc (Reagent)_Strips                    59
# Name: items, Length: 13471, dtype: int64

# %%
total_bnf_name_sort= total_bnf_name.sort_values(ascending=False)

# %%
total_bnf_name_sort
# Out:
# bnf_name
# Omeprazole_Cap E/C 20mg                     218583
# Paracet_Tab 500mg                           151669
# Aspirin Disper_Tab 75mg                     148591
# Simvastatin_Tab 40mg                        132941
# Amlodipine_Tab 5mg                          128245
#                                              ...
# Quest_Cell Life Antiox Tab                       1
# Quest_Lactase Tab                                1
# Juzo Soft Rib Style Class 1 B/Knee Close         1
# Quetiapine_Oral Soln 12.5mg/5ml                  1
# ReadyWrap Gauntlet Lymph Gmt                     1
# Name: items, Length: 13471, dtype: int64

# %%
most_common_item = [("Omeprazole_Cap E/C 20mg", 218583)]

# %%
most_common_item = [("", 0)]

# %%
grader.score.dw__most_common_item(most_common_item)
# Out:
# ==================
# Your score:  1.0
# ==================

# %% [markdown]
# ## Question 3: items_by_region
#
# Now let's find the most common item by post code. The post code information is in the `practices` DataFrame, and we'll need to `merge` it into the `scripts` DataFrame. Pandas provides [extensive documentation](https://pandas.pydata.org/pandas-docs/stable/merging.html) with diagrammed examples on different methods and approaches for joining data. The `merge` method is only one of many possible options.
#
# Return your results as a list of tuples `(post code, item name, amount dispensed as % of total)`. Sort your results ascending alphabetically by post code and take only results from the first 100 post codes.
#
# **NOTE:** Some practices have multiple postal codes associated with them. Use the alphabetically first postal code. Note some postal codes may have multiple `'bnf_name'` with the same prescription rate for the maximum. In this case, take the alphabetically first `'bnf_name'` (as in the PW miniproject).

# %% [raw]
# merged = pd.merge(scripts, practices, left_on ='practice' , right_on ='code', how='inner')
# # Group by post_code and bnf_name
# grouped_by_pc_bnfnames = merged.groupby(['post_code', 'bnf_name'])
# # Take sum of items using the group
# total_items = grouped_by_pc_bnfnames.items.sum()
# # Get the list of sorted postal codes
# postal_codes = sorted(list({id[0] for id in total_items.index}))
#
# result = []
# for post_code in postal_codes:
#     item = total_items.loc[post_code]   ## Item Data for each post code and bnf_name
#     result.append((post_code, item.idxmax(), item.max()/item.sum()))
# items_by_region = result[:100] # Extract the first 100

# %% [raw]
# # mergin=scripts.merge(scripts, practices, left_on ='practice' , right_on ='code')
# pst_code_bnfname = merged.groupby(['post_code', 'bnf_name'])
# total=grouped_by_pc_bnfnames.items.sum()
# postal_codes = sorted(list({id[0] for id in total.index}))

# %%
practices.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3c8894326229> in <module>
# ----> 1 practices.head()
#
# NameError: name 'practices' is not defined

# %%
scripts.head()
# Out:
#   practice   bnf_code                              bnf_name  items   nic  \
# 0   N85639  0106020C0                 Bisacodyl_Tab E/C 5mg      1  0.39
# 1   N85639  0106040M0      Movicol Plain_Paed Pdr Sach 6.9g      1  4.38
# 2   N85639  0301011R0    Salbutamol_Inha 100mcg (200 D) CFF      1  1.50
# 3   N85639  0304010G0  Chlorphenamine Mal_Oral Soln 2mg/5ml      1  2.62
# 4   N85639  0401020K0                      Diazepam_Tab 2mg      1  0.16
#
#    act_cost  quantity
# 0      0.47        12
# 1      4.07        30
# 2      1.40         1
# 3      2.44       150
# 4      0.26         6

# %%
practices.sort_values('post_code').head()
# Out:
#         code                               name                   addr_1  \
# 1896  E82060             PARKBURY HOUSE SURGERY           PARKBURY HOUSE
# 1871  E82031                   MALTINGS SURGERY     THE MALTINGS SURGERY
# 1849  E82004              HATFIELD ROAD SURGERY         61 HATFIELD ROAD
# 1848  E82002              WRAFTON HOUSE SURGERY    WRAFTON HOUSE SURGERY
# 9812  Y05146  HCT LYMPHOEDEMA AT WEST ESSEX CCG  QUEENSWAY HEALTH CENTRE
#
#                     addr_2    borough        village post_code
# 1896      ST.PETERS STREET  ST.ALBANS  HERTFORDSHIRE   AL1 3HD
# 1871  8-14 VICTORIA STREET  ST ALBANS  HERTFORDSHIRE   AL1 3JB
# 1849                   NaN  ST.ALBANS  HERTFORDSHIRE   AL1 4JE
# 1848   9/11 WELLFIELD ROAD   HATFIELD  HERTFORDSHIRE  AL10 0BS
# 9812             QUEENSWAY   HATFIELD  HERTFORDSHIRE  AL10 0LF

# %% [raw]
# merged = pd.merge(scripts, practices, left_on ='practice' , right_on ='code', how='inner')
# # Group by post_code and bnf_name
# grouped_by_pc_bnfnames = merged.groupby(['post_code', 'bnf_name'])
# # Take sum of items using the group
# total_items = grouped_by_pc_bnfnames.items.sum()
# # Get the list of sorted postal codes
# postal_codes = sorted(list({id[0] for id in total_items.index}))
#
# result = []
# for post_code in postal_codes:
#     item = total_items.loc[post_code]   ## Item Data for each post code and bnf_name
#     result.append((post_code, item.idxmax(), item.max()/item.sum()))
#  # Extract the first 100

# %% [raw]
# practice_unique=(practices.sort_values('post_code').drop_duplicates(subset='code', keep='first'))
# scripts_with_post_code=(scripts
#                         .merge(practice_unique, left_on='practice', right_on='code', how='inner'))
# total=(scripts_with_post_code.groupby(['post_code', 'bnf_name'])['items']
#        .sum()
#        .reset_index())
# total_by_post_code=total.groupby('post_code')['items'].sum()

# %% [raw]
# total=total.set_index('post_code').assign(total=total_by_post_code)
# total['ratio']=total['items']/total['total']
# total[total['ratio']== total['ratio'].max()]
#
# result=total.apply(lambda df: df.nlargest(1, 'ratio'))
#
# items_by_region = result[:100]

# %%
practice_unique=(practices.sort_values('post_code').drop_duplicates(subset='code', keep='first'))

# %%
scripts_with_post_code=(scripts
                        .merge(practice_unique, left_on='practice', right_on='code', how='inner'))

# %%
scripts_with_post_code.head()
# Out:
#   practice   bnf_code                              bnf_name  items   nic  \
# 0   N85639  0106020C0                 Bisacodyl_Tab E/C 5mg      1  0.39
# 1   N85639  0106040M0      Movicol Plain_Paed Pdr Sach 6.9g      1  4.38
# 2   N85639  0301011R0    Salbutamol_Inha 100mcg (200 D) CFF      1  1.50
# 3   N85639  0304010G0  Chlorphenamine Mal_Oral Soln 2mg/5ml      1  2.62
# 4   N85639  0401020K0                      Diazepam_Tab 2mg      1  0.16
#
#    act_cost  quantity    code        name                     addr_1  \
# 0      0.47        12  N85639  GP OOH VCH  VICTORIA CENTRAL HOSPITAL
# 1      4.07        30  N85639  GP OOH VCH  VICTORIA CENTRAL HOSPITAL
# 2      1.40         1  N85639  GP OOH VCH  VICTORIA CENTRAL HOSPITAL
# 3      2.44       150  N85639  GP OOH VCH  VICTORIA CENTRAL HOSPITAL
# 4      0.26         6  N85639  GP OOH VCH  VICTORIA CENTRAL HOSPITAL
#
#       addr_2   borough village post_code
# 0  MILL LANE  WALLASEY     NaN  CH44 5UF
# 1  MILL LANE  WALLASEY     NaN  CH44 5UF
# 2  MILL LANE  WALLASEY     NaN  CH44 5UF
# 3  MILL LANE  WALLASEY     NaN  CH44 5UF
# 4  MILL LANE  WALLASEY     NaN  CH44 5UF

# %%
#scripts_with_post_code=(scripts.merge(practice_unique, left_on='practice', right_on='code'))

# %%
total=(scripts_with_post_code.groupby(['post_code', 'bnf_name'])['items']
       .sum()
       .reset_index())

# %%
total.head()
# Out:
#   post_code                                  bnf_name  items
# 0   B11 4BW  3m Health Care_Cavilon Durable Barrier C      7
# 1   B11 4BW   3m Health Care_Cavilon No Sting Barrier      2
# 2   B11 4BW      Abasaglar KwikPen_100u/ml 3ml Pf Pen      2
# 3   B11 4BW                                Abidec_Dps     63
# 4   B11 4BW                Able Spacer + Sml/Med Mask      1

# %%
total_by_post_code=total.groupby('post_code')['items']. sum()
total_by_post_code.head()
# Out:
# post_code
# B11 4BW    22731
# B12 9LP    17073
# B18 7AL    20508
# B21 9RY    31027
# B23 6DJ    28011
# Name: items, dtype: int64

# %%
totals=total.set_index('post_code').assign(total=total_by_post_code)
totals['ratio']=totals['items']/totals['total']

# %%
totals.head()
# Out:
#                                            bnf_name  items  total     ratio
# post_code
# B11 4BW    3m Health Care_Cavilon Durable Barrier C      7  22731  0.000308
# B11 4BW     3m Health Care_Cavilon No Sting Barrier      2  22731  0.000088
# B11 4BW        Abasaglar KwikPen_100u/ml 3ml Pf Pen      2  22731  0.000088
# B11 4BW                                  Abidec_Dps     63  22731  0.002772
# B11 4BW                  Able Spacer + Sml/Med Mask      1  22731  0.000044

# %%
totals[totals['ratio']== totals['ratio'].max()]
# Out:
#                         bnf_name  items  total     ratio
# post_code
# TN24 0GP   Amoxicillin_Cap 500mg   1440  17829  0.080767

# %%
total.sort_values('ratio', ascending=False).iloc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-2c6e694d2997> in <module>()
# ----> 1 total.sort_values('ratio', ascending=False).iloc[0]
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4986
#    4987             by = by[0]
# -> 4988             k = self._get_label_or_level_values(by, axis=axis)
#    4989
#    4990             if isinstance(ascending, (tuple, list)):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1773             values = self.axes[axis].get_level_values(key)._values
#    1774         else:
# -> 1775             raise KeyError(key)
#    1776
#    1777         # Check for duplicates
#
# KeyError: 'ratio'

# %%
postal_codes = sorted(list({id[0] for id in total_by_post_code}))
totals=total.set_index('post_code').assign(total=total_by_post_code)
totals['ratio']=totals['items']/totals['total']
result=[]
for post_code in postal_codes
items_by_region=list(totals.nlargest(100, 'ratio'))
items_by_region
# Out:
#   File "<ipython-input-38-d6292634e9e5>", line 5
#     for post_code in postal_codes
#                                  ^
# SyntaxError: invalid syntax

# %%
results=totals.groupby('post_code').apply(lambda df: df.nlargest(1, 'ratio'))
results.head()
# Out:
#                                                bnf_name  items  total  \
# post_code post_code
# B11 4BW   B11 4BW    Salbutamol_Inha 100mcg (200 D) CFF    706  22731
# B12 9LP   B12 9LP                     Paracet_Tab 500mg    425  17073
# B18 7AL   B18 7AL    Salbutamol_Inha 100mcg (200 D) CFF    556  20508
# B21 9RY   B21 9RY               Metformin HCl_Tab 500mg   1033  31027
# B23 6DJ   B23 6DJ      Lansoprazole_Cap 30mg (E/C Gran)    599  28011
#
#                         ratio
# post_code post_code
# B11 4BW   B11 4BW    0.031059
# B12 9LP   B12 9LP    0.024893
# B18 7AL   B18 7AL    0.027111
# B21 9RY   B21 9RY    0.033294
# B23 6DJ   B23 6DJ    0.021384

# %%
result = totals.groupby('post_code', as_index=False).apply(lambda df: df.nlargest(1, 'ratio')).reset_index().set_index('post_code')

# %%
del result['level_0']
del result['items']
del result['total']

# %%
result.head()
# Out:
#                                      bnf_name     ratio
# post_code
# B11 4BW    Salbutamol_Inha 100mcg (200 D) CFF  0.031059
# B12 9LP                     Paracet_Tab 500mg  0.024893
# B18 7AL    Salbutamol_Inha 100mcg (200 D) CFF  0.027111
# B21 9RY               Metformin HCl_Tab 500mg  0.033294
# B23 6DJ      Lansoprazole_Cap 30mg (E/C Gran)  0.021384

# %%
items_by_region = result.reset_index().apply(tuple, axis=1).tolist()[:100]

# %%
items_by_region
# Out:
# [('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.031058906339360346),
#  ('B12 9LP', 'Paracet_Tab 500mg', 0.02489310607391788),
#  ('B18 7AL', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.027111371172225472),
#  ('B21 9RY', 'Metformin HCl_Tab 500mg', 0.03329358300834757),
#  ('B23 6DJ', 'Lansoprazole_Cap 30mg (E/C Gran)', 0.021384456106529576),
#  ('B61 0AZ', 'Omeprazole_Cap E/C 20mg', 0.028713318284424378),
#  ('B70 7AW', 'Paracet_Tab 500mg', 0.025135992162726547),
#  ('B72 1RL', 'Omeprazole_Cap E/C 20mg', 0.020228765092141495),
#  ('B8 1RZ', 'Metformin HCl_Tab 500mg', 0.021347750961484866),
#  ('B9 5PU', 'Ventolin_Evohaler 100mcg (200 D)', 0.024826024522257815),
#  ('B90 3LX', 'Omeprazole_Cap E/C 20mg', 0.026965103983080718),
#  ('BA5 1XJ', 'Omeprazole_Cap E/C 20mg', 0.028261290947858113),
#  ('BB11 2DL', 'Omeprazole_Cap E/C 20mg', 0.027381741821396993),
#  ('BB2 1AX', 'Omeprazole_Cap E/C 20mg', 0.03428191046763188),
#  ('BB3 1PY', 'Omeprazole_Cap E/C 20mg', 0.032683395995453356),
#  ('BB4 5SL', 'Omeprazole_Cap E/C 20mg', 0.03747689029549087),
#  ('BB4 7PL', 'Omeprazole_Cap E/C 20mg', 0.027477496877557173),
#  ('BB7 2JG', 'Omeprazole_Cap E/C 20mg', 0.027980664806967485),
#  ('BB8 0JZ', 'Atorvastatin_Tab 20mg', 0.021515746650768042),
#  ('BB9 7SR', 'Omeprazole_Cap E/C 20mg', 0.02247662283190644),
#  ('BD16 4RP', 'Lansoprazole_Cap 30mg (E/C Gran)', 0.022780283004198414),
#  ('BD19 5AP', 'Lansoprazole_Cap 30mg (E/C Gran)', 0.02066220372715759),
#  ('BD3 8QH', 'Atorvastatin_Tab 40mg', 0.031662850096882154),
#  ('BD4 7SS', 'Atorvastatin_Tab 40mg', 0.03424183501960914),
#  ('BH14 0DJ', 'Omeprazole_Cap E/C 20mg', 0.02838931332218254),
#  ('BH18 8EE', 'Omeprazole_Cap E/C 20mg', 0.027092370049064923),
#  ('BH23 3AF', 'Omeprazole_Cap E/C 20mg', 0.03546099290780142),
#  ('BL1 3RG', 'Omeprazole_Cap E/C 20mg', 0.03362566656383588),
#  ('BL1 8TU', 'Omeprazole_Cap E/C 20mg', 0.027729220222793487),
#  ('BL2 6NT', 'Omeprazole_Cap E/C 20mg', 0.0271567320510379),
#  ('BL3 5HP', 'Omeprazole_Cap E/C 20mg', 0.03129933420275929),
#  ('BL9 0NJ', 'Omeprazole_Cap E/C 20mg', 0.032037565382786494),
#  ('BL9 0SN', 'Omeprazole_Cap E/C 20mg', 0.03090454288711369),
#  ('BN1 6AG', 'Lansoprazole_Cap 15mg (E/C Gran)', 0.021755523716160168),
#  ('BN1 8DD', 'Aspirin Disper_Tab 75mg', 0.021517850460294887),
#  ('BN9 9PW', 'Omeprazole_Cap E/C 20mg', 0.01855317763853853),
#  ('BR2 9GT', 'Influenza_Vac Inact 0.5ml Pfs', 0.04301700334253742),
#  ('BR3 3FD', 'Omeprazole_Cap E/C 20mg', 0.02865911645197545),
#  ('BS16 3TD', 'Omeprazole_Cap E/C 20mg', 0.03752737892431249),
#  ('BS23 3HQ', 'Omeprazole_Cap E/C 20mg', 0.030246216399367518),
#  ('BS4 1WH', 'Omeprazole_Cap E/C 20mg', 0.029600778967867575),
#  ('BS4 4HU', 'Omeprazole_Cap E/C 20mg', 0.037361354349095155),
#  ('BS48 2XX', 'Omeprazole_Cap E/C 20mg', 0.030207346595095254),
#  ('CA11 8HW', 'Omeprazole_Cap E/C 20mg', 0.027868623340321454),
#  ('CB22 3HU', 'Omeprazole_Cap E/C 20mg', 0.038775726713346066),
#  ('CB9 8HF', 'Omeprazole_Cap E/C 20mg', 0.03391110538046382),
#  ('CH1 4DS', 'Lansoprazole_Cap 30mg (E/C Gran)', 0.0257736189772634),
#  ('CH41 8DB', 'Omeprazole_Cap E/C 20mg', 0.03327732469980738),
#  ('CH44 5UF', 'Omeprazole_Cap E/C 20mg', 0.03327334826839032),
#  ('CH62 5HS', 'Omeprazole_Cap E/C 20mg', 0.037778835690968446),
#  ('CH62 6EE', 'Influenza_Vac Inact 0.5ml Pfs', 0.057585894269547),
#  ('CH65 6TG', 'Lansoprazole_Cap 30mg (E/C Gran)', 0.026067517902474142),
#  ('CH66 3PB', 'Lansoprazole_Cap 30mg (E/C Gran)', 0.03100619319552803),
#  ('CM18 6LY', 'Omeprazole_Cap E/C 20mg', 0.026445315758738635),
#  ('CR0 0JA', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.021571724750715768),
#  ('CT11 8AD', 'Omeprazole_Cap E/C 20mg', 0.022307039864291774),
#  ('CV1 4FS', 'Omeprazole_Cap E/C 20mg', 0.028455180531743392),
#  ('CV12 8NQ', 'Omeprazole_Cap E/C 20mg', 0.026444799282852902),
#  ('CV21 2DN', 'Omeprazole_Cap E/C 20mg', 0.04102890311294875),
#  ('CV6 2FL', 'Omeprazole_Cap E/C 20mg', 0.036250663502669624),
#  ('CV6 6DR', 'Omeprazole_Cap E/C 20mg', 0.030544721504009817),
#  ('CW1 3AW', 'Omeprazole_Cap E/C 20mg', 0.03558258199497268),
#  ('CW5 5NX', 'Omeprazole_Cap E/C 20mg', 0.03453647138997736),
#  ('CW7 1AT', 'Omeprazole_Cap E/C 20mg', 0.03666371289322109),
#  ('DA1 2HA', 'Omeprazole_Cap E/C 20mg', 0.019244977658938185),
#  ('DA11 8BZ', 'Amoxicillin_Cap 500mg', 0.019686834904226208),
#  ('DN16 2AB', 'Amlodipine_Tab 5mg', 0.019925280199252802),
#  ('DN22 7XF', 'Simvastatin_Tab 40mg', 0.018624361621210474),
#  ('DN31 3AE', 'Omeprazole_Cap E/C 20mg', 0.03432952436761402),
#  ('DN34 4GB', 'Omeprazole_Cap E/C 20mg', 0.03709507845509909),
#  ('DN6 0HZ', 'Paracet_Tab 500mg', 0.025764099668243102),
#  ('DN8 4BQ', 'Lansoprazole_Cap 30mg (E/C Gran)', 0.021703061442945835),
#  ('DY11 6SF', 'Omeprazole_Cap E/C 20mg', 0.021081859317153433),
#  ('E15 4ES', 'Amlodipine_Tab 10mg', 0.02569068641412703),
#  ('E7 0EP', 'Metformin HCl_Tab 500mg', 0.037244933982913224),
#  ('FY2 0JG', 'Omeprazole_Cap E/C 20mg', 0.03627638093657511),
#  ('FY4 1TJ', 'Omeprazole_Cap E/C 20mg', 0.04334478808705613),
#  ('FY5 2TZ', 'Omeprazole_Cap E/C 20mg', 0.03540407051009112),
#  ('FY5 3LF', 'Omeprazole_Cap E/C 20mg', 0.035122866094073016),
#  ('FY7 8GU', 'Omeprazole_Cap E/C 20mg', 0.032058079778122195),
#  ('FY8 5DZ', 'Omeprazole_Cap E/C 20mg', 0.02969960416717259),
#  ('GL1 3PX', 'Omeprazole_Cap E/C 20mg', 0.025687801991914012),
#  ('GL20 5GJ', 'Omeprazole_Cap E/C 20mg', 0.02412690753362688),
#  ('GL50 4DP', 'Omeprazole_Cap E/C 20mg', 0.024009042366605605),
#  ('GU9 9QS', 'Omeprazole_Cap E/C 20mg', 0.027052485943893322),
#  ('HA0 4UZ', 'Metformin HCl_Tab 500mg', 0.027855843941147297),
#  ('HA3 7LT', 'Omeprazole_Cap E/C 20mg', 0.02504635488712953),
#  ('HD6 1AT', 'Lansoprazole_Cap 30mg (E/C Gran)', 0.021017471736896196),
#  ('HG1 5AR', 'Omeprazole_Cap E/C 20mg', 0.02842489568845619),
#  ('HR1 2JB', 'Omeprazole_Cap E/C 20mg', 0.028529603122966818),
#  ('HR6 8HD', 'Omeprazole_Cap E/C 20mg', 0.027207967812149594),
#  ('HU7 4DW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.025607843137254904),
#  ('HU9 2LJ', 'Lansoprazole_Cap 30mg (E/C Gran)', 0.0243192109011288),
#  ('IG7 4DF', 'Amlodipine_Tab 5mg', 0.01956475808155504),
#  ('IP22 4WG', 'Omeprazole_Cap E/C 20mg', 0.02851095218241878),
#  ('KT12 3LB', 'Omeprazole_Cap E/C 20mg', 0.01828471919895516),
#  ('KT14 6DH', 'Amlodipine_Tab 5mg', 0.018667887710894296),
#  ('KT16 8HZ', 'Amlodipine_Tab 5mg', 0.019319714781268066),
#  ('KT6 6EZ', 'Omeprazole_Cap E/C 20mg', 0.02821316614420063),
#  ('L31 0DJ', 'Omeprazole_Cap E/C 20mg', 0.029425653739448675)]

# %%
#items_by_region = [("B11 4BW", "Salbutamol_Inha 100mcg (200 D) CFF", 0.0310589063)] * 100

# %%
grader.score.dw__items_by_region(items_by_region)
# Out:
# ==================
# Your score:  1.0
# ==================

# %% [markdown]
# ## Question 4: script_anomalies
#
# Drug abuse is a source of human and monetary costs in health care. A first step in identifying practitioners that enable drug abuse is to look for practices where commonly abused drugs are prescribed unusually often. Let's try to find practices that prescribe an unusually high amount of opioids. The opioids we'll look for are given in the list below.

# %%
opioids = ['morphine', 'oxycodone', 'methadone', 'fentanyl', 'pethidine', 'buprenorphine', 'propoxyphene', 'codeine']

# %% [markdown]
# These are generic names for drugs, not brand names. Generic drug names can be found using the `'bnf_code'` field in `scripts` along with the `chem` table.. Use the list of opioids provided above along with these fields to make a new field in the `scripts` data that flags whether the row corresponds with a opioid prescription.

# %%
chem.head()
# Out:
#     CHEM SUB                                NAME
# 0  0101010A0                     Alexitol Sodium
# 1  0101010B0                          Almasilate
# 2  0101010C0                 Aluminium Hydroxide
# 3  0101010D0  Aluminium Hydroxide With Magnesium
# 4  0101010E0                        Hydrotalcite

# %%
#they are certain chem name with the sub value

chem['CHEM SUB'].nunique()  #assuming
# Out:
# 3481

# %%
chem=chem.sort_values('CHEM SUB').drop_duplicates(subset='CHEM SUB', keep='first')

# %%
any([True, True, False, False])
# Out:
# True

# %%
any([False, False, False, False])
# Out:
# False

# %%
chem['NAME'].apply(lambda x: any([oploid in x for oploid in opioids]))
# Out:
# 18      False
# 0       False
# 1       False
# 2       False
# 3       False
#         ...
# 3427    False
# 3428    False
# 3429    False
# 3430    False
# 3431    False
# Name: NAME, Length: 3481, dtype: bool

# %%
ind=chem['NAME'].apply(lambda x: any([oploid in x.lower() for oploid in opioids]))

# %%
chem[ind]
# Out:
#        CHEM SUB                                      NAME
# 88    0104020D0       Codeine Phosphate Compound Mixtures
# 91    0104020N0                          Opium & Morphine
# 691   0309010C0                         Codeine Phosphate
# 693   0309010N0                 Diamorphine Hydrochloride
# 695   0309010S0                   Methadone Hydrochloride
# 701   0309020AC                        Guaiacol & Codeine
# 955   0407010F0     Co-Codamol (Codeine Phos/Paracetamol)
# 959   0407010M0        Co-Codaprin (Codeine Phos/Aspirin)
# 960   0407010N0      Co-Dydramol (Dihydrocodeine/Paracet)
# 963   0407010R0  Aspirin Phenacetin & Codeine(Codeine Co)
# 965   0407010T0             Aspirin Paracetamol & Codeine
# 967   0407010V0           Paracetamol & Codeine Phosphate
# 1002  040702010                        Morphine Anhydrous
# 1003  040702020    Morphine Tartrate & Cyclizine Tartrate
# 981   0407020A0                                  Fentanyl
# 977   0407020AD                   Oxycodone Hydrochloride
# 978   0407020AE           Diamorphine Hydrochloride (Top)
# 979   0407020AF                Oxycodone HCl/Naloxone HCl
# 982   0407020B0                             Buprenorphine
# 983   0407020C0                         Codeine Phosphate
# 985   0407020E0                        Dextropropoxyphene
# 986   0407020G0                   Dihydrocodeine Tartrate
# 989   0407020K0      Diamorphine Hydrochloride (Systemic)
# 991   0407020M0                   Methadone Hydrochloride
# 992   0407020N0                                  Morphine
# 993   0407020P0                    Morphine Hydrochloride
# 994   0407020Q0                          Morphine Sulfate
# 997   0407020V0                   Pethidine Hydrochloride
# 1001  0407020Z0                                 Oxycodone
# 1072  0409010A0                 Apomorphine Hydrochloride
# 1114  0410030A0               Buprenorphine Hydrochloride
# 1116  0410030C0                   Methadone Hydrochloride
# 1816  0704050G0                 Apomorphine Hydrochloride
# 3246  1501043F0                          Fentanyl Citrate
# 3276  1502010Z0  Bupivacaine Hydrochloride & Fentanyl Cit

# %%
opioids
# Out:
# ['morphine',
#  'oxycodone',
#  'methadone',
#  'fentanyl',
#  'pethidine',
#  'buprenorphine',
#  'propoxyphene',
#  'codeine']

# %%
re_opidoid="|".join(opioids)
print(re_opidoid)
# Out:
# morphine|oxycodone|methadone|fentanyl|pethidine|buprenorphine|propoxyphene|codeine

# %%
chem['is_opioid']= chem['NAME'].str.lower().str.contains(re_opidoid)

# %%
chem.head()
# Out:
#     CHEM SUB                                NAME  is_opioid
# 0  0101010A0                     Alexitol Sodium      False
# 1  0101010B0                          Almasilate      False
# 2  0101010C0                 Aluminium Hydroxide      False
# 3  0101010D0  Aluminium Hydroxide With Magnesium      False
# 4  0101010E0                        Hydrotalcite      False

# %%
chem['NAME'].str.lower().str.contains(r'morphine|oxycodone|methadone|fentanyl|')
# Out:
# 18      True
# 0       True
# 1       True
# 2       True
# 3       True
#         ...
# 3427    True
# 3428    True
# 3429    True
# 3430    True
# 3431    True
# Name: NAME, Length: 3481, dtype: bool

# %% [markdown]
# Now for each practice calculate the proportion of its prescriptions containing opioids.
#
# **Hint:** Consider the following list: `[0, 1, 1, 0, 0, 0]`. What proportion of the entries are 1s? What is the mean value?

# %%
scripts_w_opioid=scripts.merge(chem, left_on= 'bnf_code', right_on='CHEM SUB', how='left')

# %%
scripts_w_opioid.head()
# Out:
#   practice   bnf_code                              bnf_name  items   nic  \
# 0   N85639  0106020C0                 Bisacodyl_Tab E/C 5mg      1  0.39
# 1   N85639  0106040M0      Movicol Plain_Paed Pdr Sach 6.9g      1  4.38
# 2   N85639  0301011R0    Salbutamol_Inha 100mcg (200 D) CFF      1  1.50
# 3   N85639  0304010G0  Chlorphenamine Mal_Oral Soln 2mg/5ml      1  2.62
# 4   N85639  0401020K0                      Diazepam_Tab 2mg      1  0.16
#
#    act_cost  quantity   CHEM SUB                    NAME is_opioid
# 0      0.47        12  0106020C0               Bisacodyl     False
# 1      4.07        30  0106040M0           Macrogol 3350     False
# 2      1.40         1  0301011R0              Salbutamol     False
# 3      2.44       150  0304010G0  Chlorphenamine Maleate     False
# 4      0.26         6  0401020K0                Diazepam     False

# %%
scripts_w_opioid=(scripts.merge(chem, left_on= 'bnf_code', right_on='CHEM SUB', how='left').fillna(False))

# %%
scripts_w_opioid['is_opioid'].isna().sum()
# Out:
# 0

# %%
scripts_w_opioid.groupby('practice')['is_opioid'].mean()
# Out:
# practice
# A81005    0.033179
# A81007    0.043329
# A81011    0.046556
# A81012    0.042793
# A81017    0.038140
#             ...
# Y05570    0.090909
# Y05583    0.000000
# Y05597    0.000000
# Y05660    0.023055
# Y05670    0.000000
# Name: is_opioid, Length: 856, dtype: float64

# %%
opioid_per_practice =scripts_w_opioid.groupby('practice')['is_opioid'].mean()

# %%
opioid_per_practice
# Out:
# practice
# A81005    0.033179
# A81007    0.043329
# A81011    0.046556
# A81012    0.042793
# A81017    0.038140
#             ...
# Y05570    0.090909
# Y05583    0.000000
# Y05597    0.000000
# Y05660    0.023055
# Y05670    0.000000
# Name: is_opioid, Length: 856, dtype: float64

# %% [markdown]
# How do these proportions compare to the overall opioid prescription rate? Subtract off the proportion of all prescriptions that are opioids from each practice's proportion.

# %%
relative_opioids_per_practice = opioid_per_practice- scripts_w_opioid['is_opioid'].mean()

# %%
relative_opioids_per_practice
# Out:
# practice
# A81005   -0.002624
# A81007    0.007526
# A81011    0.010753
# A81012    0.006990
# A81017    0.002337
#             ...
# Y05570    0.055106
# Y05583   -0.035803
# Y05597   -0.035803
# Y05660   -0.012748
# Y05670   -0.035803
# Name: is_opioid, Length: 856, dtype: float64

# %% [markdown]
# Now that we know the difference between each practice's opioid prescription rate and the overall rate, we can identify which practices prescribe opioids at above average or below average rates. However, are the differences from the overall rate important or just random deviations? In other words, are the differences from the overall rate big or small?
#
# To answer this question we have to quantify the difference we would typically expect between a given practice's opioid prescription rate and the overall rate. This quantity is called the **standard error**, and is related to the **standard deviation**, $\sigma$. The standard error in this case is
#
# $$ \frac{\sigma}{\sqrt{n}} $$
#
# where $n$ is the number of prescriptions each practice made. Calculate the standard error for each practice. Then divide `relative_opioids_per_practice` by the standard errors. We'll call the final result `opioid_scores`.

# %%
sigma=scripts_w_opioid['is_opioid'].std()

#standard_error_per_practice = scripts_w_opioid['is_opioid'].std()
#opioid_scores = ...

# %%
sigma
# Out:
# 0.18579817605238425

# %%
scripts_w_opioid.groupby('practice')['is_opioid'].count()
# Out:
# practice
# A81005    1507
# A81007    1454
# A81011    1568
# A81012    1332
# A81017    2150
#           ...
# Y05570      22
# Y05583      28
# Y05597      18
# Y05660     347
# Y05670      12
# Name: is_opioid, Length: 856, dtype: int64

# %%
count_per_pac=scripts_w_opioid.groupby('practice')['is_opioid'].count()

# %%
count_per_pac
# Out:
# practice
# A81005    1509
# A81007    1456
# A81011    1569
# A81012    1333
# A81017    2151
#           ...
# Y05570      22
# Y05583      28
# Y05597      18
# Y05660     347
# Y05670      12
# Name: is_opioid, Length: 856, dtype: int64

# %%
counts_per_practice=scripts_w_opioid['practice'].value_counts()

# %%
standard_error_per_practice=sigma / counts_per_practice ** 0.5
opioid_score=relative_opioids_per_practice / standard_error_per_practice

# %%
opioid_score
# Out:
# A81005   -0.548306
# A81007    1.544557
# A81011    2.291795
# A81012    1.373060
# A81017    0.583168
#             ...
# Y05570    1.391142
# Y05583   -1.019657
# Y05597   -0.817544
# Y05660   -1.278102
# Y05670   -0.667522
# Length: 856, dtype: float64

# %%
counts_per_practice
# Out:
# N83028    2844
# L83100    2797
# D81043    2459
# B81008    2396
# B81026    2347
#           ...
# C85617       1
# Y03179       1
# Y03472       1
# Y03010       1
# Y05366       1
# Name: practice, Length: 856, dtype: int64

# %%
standard_error_per_practice=sigma / counts_per_practice ** 0.5
opioid_score=relative_opioids_per_practice / standard_error_per_practice
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-bcddc521151c> in <module>()
# ----> 1 standard_error_per_practice=sigma / counts_per_pactice ** 0.5
#       2 opioid_score=relative_opioids_per_practice / standard_error_per_practice
#
# NameError: name 'counts_per_pactice' is not defined

# %%
standard_error_per_practice
# Out:
# N83028    0.003484
# L83100    0.003513
# D81043    0.003747
# B81008    0.003796
# B81026    0.003835
#             ...
# C85617    0.185798
# Y03179    0.185798
# Y03472    0.185798
# Y03010    0.185798
# Y05366    0.185798
# Name: practice, Length: 856, dtype: float64

# %%
opioid_score
# Out:
# A81005   -0.548306
# A81007    1.544557
# A81011    2.291795
# A81012    1.373060
# A81017    0.583168
#             ...
# Y05570    1.391142
# Y05583   -1.019657
# Y05597   -0.817544
# Y05660   -1.278102
# Y05670   -0.667522
# Length: 856, dtype: float64

# %% [markdown]
# The quantity we have calculated in `opioid_scores` is called a **z-score**:
#
# $$ \frac{\bar{X} - \mu}{\sqrt{\sigma^2/n}} $$
#
# Here $\bar{X}$ corresponds with the proportion for each practice, $\mu$ corresponds with the proportion across all practices, $\sigma^2$ corresponds with the variance of the proportion across all practices, and $n$ is the number of prescriptions made by each practice. Notice $\bar{X}$ and $n$ will be different for each practice, while $\mu$ and $\sigma$ are determined across all prescriptions, and so are the same for every z-score. The z-score is a useful statistical tool used for hypothesis testing, finding outliers, and comparing data about different types of objects or events.
#
# Now that we've calculated this statistic, take the 100 practices with the largest z-score. Return your result as a list of tuples in the form `(practice_name, z-score, number_of_scripts)`. Sort your tuples by z-score in descending order. Note that some practice codes will correspond with multiple names. In this case, use the first match when sorting names alphabetically.

# %%
unique_practices = practices.sort_values('name').drop_duplicates(subset='code', keep='first')
unique_practices
#anomalies = [("NATIONAL ENHANCED SERVICE", 11.6958178629, 7)] * 100
# Out:
#          code                                      name  \
# 7012   P87657  (IRLAM) SALFORD CARE CTRS MEDICAL PRACTI
# 10922  Y05381        0-19 EAST CHESHIRE HEALTH VISITORS
# 11984  Y04082     0-19 PUBLIC HEALTH SERVICE HARTLEPOOL
# 7573   Y00364                             1 TO 1 CENTRE
# 6836   P87652        1/LOWER BROUGHTON MEDICAL PRACTICE
# ...       ...                                       ...
# 5099   M83013                                    YOXALL
# 9872   Y05235                 YPS SSM SERVICE (REFRESH)
# 2088   E84653                       ZAIN MEDICAL CENTRE
# 6614   P92005                                     ZAMAN
# 44     A81048                  ZETLAND MEDICAL PRACTICE
#
#                          addr_1                     addr_2  \
# 7012    SALFORD CARE CTR(IRLAM)         125 LIVERPOOL ROAD
# 10922            SALINAE CLINIC               LEWIN STREET
# 11984  CHATHAM CHILDRENS CENTRE            29 CHATHAM ROAD
# 7573            BRENKLEY AVENUE                  SHIREMOOR
# 6836   LOWER BROUGHTON HTH.CTR.        GREAT CLOWES STREET
# ...                         ...                        ...
# 5099       YOXALL HEALTH CENTRE         SAVEY LANE  YOXALL
# 9872            KENWORTHY HOUSE       98-104 GEORGE STREET
# 2088            122 TURNER ROAD                        NaN
# 6614             CHANDLER HOUSE  WORSLEY MESNES HEALTH CTR
# 44              WINDY HILL LANE          MARSKE BY THE SEA
#
#                    borough            village post_code
# 7012                 IRLAM         MANCHESTER   M44 6DP
# 10922           MIDDLEWICH           CHESHIRE  CW10 9FG
# 11984           HARTLEPOOL                NaN  TS24 8QG
# 7573   NEWCASTLE UPON TYNE                NaN  NE27 0PR
# 6836               SALFORD                NaN    M7 1RD
# ...                    ...                ...       ...
# 5099       BURTON ON TRENT      STAFFORDSHIRE  DE13 8PD
# 9872                  HULL     EAST YORKSHIRE   HU1 3DT
# 2088               EDGWARE          MIDDLESEX   HA8 6BH
# 6614        POOLSTOCK LANE  WIGAN  LANCASHIRE   WN3 5HL
# 44                  REDCAR          CLEVELAND  TS11 7BL
#
# [10843 rows x 7 columns]

# %%
unique_practices=unique_practices.set_index('code')

# %%
unique_practices['z_score']= opioid_score
unique_practices['counts']= counts_per_practice

# %%
output=unique_practices[['name', 'z_score', 'counts']].sort_values('z_score', ascending=False)
anomalies=output.head(100)

# %%
#anomalies = output.reset_index().apply(tuple, axis=1).tolist()[:100]

# %%
#lapply(output, function(x) x[!(names(x) %in% c("ID", "Value"))])

# %%
grader.score.dw__script_anomalies(anomalies)
# Out:
# ==================
# Your score:  1.0
# ==================

# %% [markdown]
# ## Question 5: script_growth
#
# Another way to identify anomalies is by comparing current data to historical data. In the case of identifying sites of drug abuse, we might compare a practice's current rate of opioid prescription to their rate 5 or 10 years ago. Unless the nature of the practice has changed, the profile of drugs they prescribe should be relatively stable. We might also want to identify trends through time for business reasons, identifying drugs that are gaining market share. That's what we'll do in this question.
#
# We'll load in beneficiary data from 6 months earlier, June 2016, and calculate the percent growth in prescription rate from June 2016 to January 2017 for each `bnf_name`. We'll return the 50 items with largest growth and the 50 items with the largest shrinkage (i.e. negative percent growth) as a list of tuples sorted by growth rate in descending order in the format `(script_name, growth_rate, raw_2016_count)`. You'll notice that many of the 50 fastest growing items have low counts of prescriptions in 2016. Filter out any items that were prescribed less than 50 times.

# %%
scripts16 = pd.read_csv('dw-data/201606scripts_sample.csv.gz')

# %%
scripts16.head()
# Out:
#   practice   bnf_code                                 bnf_name  items   nic  \
# 0   N85638  0301011R0   Salamol_Inha 100mcg (200 D) CFF (Teva)      2  2.92
# 1   N85638  0301011R0  Easyhaler_Salbutamol Sulf 200mcg (200D)      1  6.63
# 2   N85638  0301020I0     Ipratrop Brom_Inh Soln 500mcg/2ml Ud      1  1.77
# 3   N85638  0301020I0     Ipratrop Brom_Inh Soln 250mcg/1ml Ud      1  4.47
# 4   N85638  0302000C0        Clenil Modulite_Inha 50mcg (200D)      1  3.70
#
#    act_cost  quantity
# 0      2.73         2
# 1      6.15         1
# 2      1.75        12
# 3      4.15        20
# 4      3.44         1

# %%
#scripts=scripts.sort_values('bnf_name').drop_duplicates(subset='bnf_name', keep='first')

# %%
#finding total number drugs. ow many time for each bnf_name is prescribed

scripts.groupby('bnf_name')['items'].count()
# Out:
# bnf_name
# 365 Film 10cm x 12cm VP Adh Film Dress      1
# 365 Non Adherent 10cm x 10cm Pfa Plas Fa    3
# 365 Non Adherent 10cm x 20cm Pfa Plas Fa    1
# 365 Non Woven Island 8cm x 10cm Adh Dres    1
# 365 Transpt Island 5cm x 7.2cm VP Adh Fi    2
#                                            ..
# nSpire PiKo-1 Stnd Range Peak Flow Meter    1
# nSpire Pocket Peak Low Range Peak Flow M    4
# nSpire Pocket Peak Stnd Range Peak Flow     5
# oraNurse_Toothpaste Orig (1450ppm)          4
# palmdoc (Reagent)_Strips                    5
# Name: items, Length: 13471, dtype: int64

# %%
scripts['bnf_name'].value_counts()
# Out:
# GlucoRX FinePoint Needles Pen Inj Screw     1718
# 3m Health Care_Cavilon Durable Barrier C     816
# Prednisolone_Tab 5mg                         785
# Fluclox Sod_Cap 500mg                        783
# Amoxicillin_Cap 500mg                        777
#                                             ...
# Oprymea_Tab 1.05mg M/R                         1
# P.Grip CS.01 Retaining Strap Cath Access       1
# Edronax_Tab 4mg                                1
# Tielle Sacrum 18cm x 18cm Wound Dress Po       1
# Carbamazepine_Suppos 250mg                     1
# Name: bnf_name, Length: 13471, dtype: int64

# %%
pct_growth=(scripts['bnf_name'].value_counts()/scripts16['bnf_name'].value_counts())-1

# %%
pct_growth=pct_growth.rename('pct_growth')
pct_growth
# Out:
# 365 Film 10cm x 12cm VP Adh Film Dress           NaN
# 365 Film 15cm x 20cm VP Adh Film Dress           NaN
# 365 Film 4cm x 5cm VP Adh Film Dress             NaN
# 365 Non Adherent 10cm x 10cm Pfa Plas Fa    0.000000
# 365 Non Adherent 10cm x 20cm Pfa Plas Fa         NaN
#                                               ...
# nSpire PiKo-1 Stnd Range Peak Flow Meter   -0.500000
# nSpire Pocket Peak Low Range Peak Flow M    1.000000
# nSpire Pocket Peak Stnd Range Peak Flow     1.500000
# oraNurse_Toothpaste Orig (1450ppm)          1.000000
# palmdoc (Reagent)_Strips                    0.666667
# Name: pct_growth, Length: 15424, dtype: float64

# %%
pct_growth.to_frame()
# Out:
#                                           pct_growth
# 365 Film 10cm x 12cm VP Adh Film Dress           NaN
# 365 Film 15cm x 20cm VP Adh Film Dress           NaN
# 365 Film 4cm x 5cm VP Adh Film Dress             NaN
# 365 Non Adherent 10cm x 10cm Pfa Plas Fa    0.000000
# 365 Non Adherent 10cm x 20cm Pfa Plas Fa         NaN
# ...                                              ...
# nSpire PiKo-1 Stnd Range Peak Flow Meter   -0.500000
# nSpire Pocket Peak Low Range Peak Flow M    1.000000
# nSpire Pocket Peak Stnd Range Peak Flow     1.500000
# oraNurse_Toothpaste Orig (1450ppm)          1.000000
# palmdoc (Reagent)_Strips                    0.666667
#
# [15424 rows x 1 columns]

# %%
df_script_growth=pct_growth.to_frame()
df_script_growth['raw_counts']= scripts16['bnf_name'].value_counts()
df_script_growth.head()
# Out:
#                                           pct_growth  raw_counts
# 365 Film 10cm x 12cm VP Adh Film Dress           NaN         NaN
# 365 Film 15cm x 20cm VP Adh Film Dress           NaN         1.0
# 365 Film 4cm x 5cm VP Adh Film Dress             NaN         1.0
# 365 Non Adherent 10cm x 10cm Pfa Plas Fa         0.0         3.0
# 365 Non Adherent 10cm x 20cm Pfa Plas Fa         NaN         NaN

# %%
df_script_growth[df_script_growth['raw_counts'] >= 50]
# Out:
#                                           pct_growth  raw_counts
# 3m Health Care_Cavilon Durable Barrier C   -0.010909       825.0
# 3m Health Care_Cavilon No Sting 1ml Barr   -0.034632       231.0
# 3m Health Care_Cavilon No Sting 3ml Barr   -0.104762       105.0
# 3m Health Care_Cavilon No Sting Barrier    -0.092511       454.0
# A.S Saliva Orthana Spy 50ml (App)           0.440476        84.0
# ...                                              ...         ...
# Zuclopenth Decan_Inj 200mg/ml 1ml Amp      -0.383562        73.0
# Zuclopenth Decan_Inj 500mg/ml 1ml Amp      -0.259259        54.0
# Zuclopenth HCl_Tab 10mg                     0.051724       116.0
# Zuclopenth HCl_Tab 2mg                      0.014085        71.0
# Zumenon_Tab 1mg                            -0.215686        51.0
#
# [3519 rows x 2 columns]

# %%
df_script_growth.query('raw_counts >= 50')
# Out:
#                                           pct_growth  raw_counts
# 3m Health Care_Cavilon Durable Barrier C   -0.010909       825.0
# 3m Health Care_Cavilon No Sting 1ml Barr   -0.034632       231.0
# 3m Health Care_Cavilon No Sting 3ml Barr   -0.104762       105.0
# 3m Health Care_Cavilon No Sting Barrier    -0.092511       454.0
# A.S Saliva Orthana Spy 50ml (App)           0.440476        84.0
# ...                                              ...         ...
# Zuclopenth Decan_Inj 200mg/ml 1ml Amp      -0.383562        73.0
# Zuclopenth Decan_Inj 500mg/ml 1ml Amp      -0.259259        54.0
# Zuclopenth HCl_Tab 10mg                     0.051724       116.0
# Zuclopenth HCl_Tab 2mg                      0.014085        71.0
# Zumenon_Tab 1mg                            -0.215686        51.0
#
# [3519 rows x 2 columns]

# %%
df_script_growth= (df_script_growth.query('raw_counts >= 50')
                   .dropna()
                   .reset_index()
                   .rename({'index': 'bnf_name'}, axis=1) # rename the index to bnf_name
                   .sort_values('pct_growth'))

df_script_growth
# Out:
#      bnf_name  level_0                                  bnf_name  pct_growth  \
# 2613     2613     2613                      Polyalc_Eye Dps 1.4%   -0.996324
# 627       627      627                              Climesse_Tab   -0.942029
# 625       625      625                          Climaval_Tab 1mg   -0.926471
# 2471     2471     2471                               Ovysmen_Tab   -0.925373
# 1623     1623     1623        Hydroxyzine HCl_Oral Soln 10mg/5ml   -0.914894
# ...       ...      ...                                       ...         ...
# 3033     3033     3033  Spiolto Respimat_Inha2.5/2.5mcg(60D)+Dev    1.269231
# 2612     2612     2612     Pneumococcal_Vac 0.5ml Vl (23 Valent)    1.269430
# 1409     1409     1409  Fostair NEXThaler_Inh 200mcg/6mcg (120D)    1.430233
# 430       430      430          Butec_Transdermal Patch 10mcg/hr    3.000000
# 431       431      431           Butec_Transdermal Patch 5mcg/hr    3.467742
#
#       raw_counts
# 2613       272.0
# 627         69.0
# 625        136.0
# 2471        67.0
# 1623        94.0
# ...          ...
# 3033        52.0
# 2612       193.0
# 1409        86.0
# 430         69.0
# 431         62.0
#
# [3485 rows x 5 columns]

# %%
pct_growth=(scripts['bnf_name'].value_counts()/scripts16['bnf_name'].value_counts())-1

# %%
#combining pieces code in to one cell
df_script_growth=(pct_growth
                 .rename('pct_growth')
                 .to_frame()
                 .assign(raw_counts=scripts16['bnf_name'].value_counts())
                 .query('raw_counts >= 50')
                 .dropna()
                 .reset_index()
                 .rename({'index': 'bnf_name'}, axis=1)
                 .sort_values('pct_growth', ascending=False))
df_script_growth.head(50)
# Out:
#                                       bnf_name  pct_growth  raw_counts
# 431            Butec_Transdermal Patch 5mcg/hr    3.467742        62.0
# 430           Butec_Transdermal Patch 10mcg/hr    3.000000        69.0
# 1409  Fostair NEXThaler_Inh 200mcg/6mcg (120D)    1.430233        86.0
# 2612     Pneumococcal_Vac 0.5ml Vl (23 Valent)    1.269430       193.0
# 3033  Spiolto Respimat_Inha2.5/2.5mcg(60D)+Dev    1.269231        52.0
# 3257          Trulicity_Inj 1.5mg/0.5ml Pf Pen    1.185185        54.0
# 854           CosmoCol_Paed Oral Pdr Sach 6.9g    1.177419        62.0
# 1077        Dulaglutide_Inj 1.5mg/0.5ml Pf Dev    0.963415        82.0
# 3375   ViATIM_Vac D/Chamber 160u/25mcg 1ml Pfs    0.912000       125.0
# 1140                    Empagliflozin_Tab 25mg    0.896000       125.0
# 503           CareSens Lancets 0.31mm/30 Gauge    0.895522        67.0
# 1411        Fostair_Inh 200mcg/6mcg (120D) CFF    0.861660       253.0
# 2462   Orbis Nor Saline Sod Chlor 0.9% Nsl Dps    0.858824        85.0
# 3282         Umeclidinium Brom_Inh 65mcg (30D)    0.827586        87.0
# 3279      Ultibro Breezhaler_Pdr Inh Cap + Dev    0.801653       121.0
# 2041                     Medihoney_Barrier Crm    0.784091        88.0
# 1346     Fluoxetine HCl_Oral Soln 20mg/5ml S/F    0.780822        73.0
# 3095                     TEE2 (Reagent)_Strips    0.777778        81.0
# 3430                      Zaluron XL_Tab 400mg    0.758621        58.0
# 1873      Laxido_Paed Plain Oral Pdr Sach 6.9g    0.758621       174.0
# 2641         Prednisolone_Oral Soln 5mg/5ml Ud    0.726027        73.0
# 416        Buprenorphine_Patch 15mcg/hr (7day)    0.715596       109.0
# 795   Coloplast_SenSura Mio Maxi Drnbl Bag S/C    0.703704        81.0
# 2382           Octenisan_Antimicrobial Wsh Lot    0.702703        74.0
# 1076        Duaklir Genuair_340mcg/12mcg (60D)    0.671053       152.0
# 2992      Sod Chlor_Inh Soln 0.9% 2.5ml Ud Amp    0.641975       162.0
# 794   Coloplast_SenSura Mio Maxi Drnbl Bag L/C    0.627451        51.0
# 1375            Flutiform_Inha 50/5mcg (120 D)    0.625000        88.0
# 1688           Ins Degludec_100u/ml 3ml Pf Pen    0.616667        60.0
# 504           CareSens Lancets 0.36mm/28 Gauge    0.611111        90.0
# 1177                           Epimax Crm 500g    0.610000       100.0
# 1243             Evacal D3_Tab Chble 400u/1.5g    0.604651        86.0
# 2946                          Shortec_Cap 20mg    0.602941        68.0
# 717   Co-Trimoxazole_Oral Susp 40/200mg/5mlS/F    0.600000        50.0
# 595      Ciprofloxacin_Gran For Susp 250mg/5ml    0.592105        76.0
# 71    AgaMatrix Ultra-Thin Lancets 0.35mm/28 G    0.566038        53.0
# 3436                  Zemtard 120 XL_Cap 120mg    0.563636        55.0
# 2370                    Nutramigen 2 + LGG_Pdr    0.560440        91.0
# 3210      Toujeo_300u/ml 1.5ml Pf SoloStar Pen    0.540881       159.0
# 1722  Ins Tresiba_FlexTouch 100u/ml 3ml Pf Pen    0.540541       148.0
# 1954                      Longtec_Tab 30mg M/R    0.537037       108.0
# 44                              Adalat_Cap 5mg    0.536585        82.0
# 953             Dexameth_Oral Soln 2mg/5ml S/F    0.529412        68.0
# 1574            Haloperidol_Inj 5mg/ml 1ml Amp    0.528846       104.0
# 1989                     Lyclear_Dermal Crm 5%    0.521127        71.0
# 3334        Valupak_Multivit & Mineral Tab OAD    0.509804        51.0
# 800   Coloplast_Sensura Mio Maxi Clsd Bag + Fl    0.505618        89.0
# 2042                     Medikinet XL_Cap 10mg    0.484848        99.0
# 1056                        Dovobet_Gel Applic    0.481481        54.0
# 1674           Incruse Ellipta_Inh 55mcg (30D)    0.480769       208.0

# %%
df_script_growth.head(50)
# Out:
#                                       bnf_name  pct_growth  raw_counts
# 431            Butec_Transdermal Patch 5mcg/hr    3.467742        62.0
# 430           Butec_Transdermal Patch 10mcg/hr    3.000000        69.0
# 1409  Fostair NEXThaler_Inh 200mcg/6mcg (120D)    1.430233        86.0
# 2612     Pneumococcal_Vac 0.5ml Vl (23 Valent)    1.269430       193.0
# 3033  Spiolto Respimat_Inha2.5/2.5mcg(60D)+Dev    1.269231        52.0
# 3257          Trulicity_Inj 1.5mg/0.5ml Pf Pen    1.185185        54.0
# 854           CosmoCol_Paed Oral Pdr Sach 6.9g    1.177419        62.0
# 1077        Dulaglutide_Inj 1.5mg/0.5ml Pf Dev    0.963415        82.0
# 3375   ViATIM_Vac D/Chamber 160u/25mcg 1ml Pfs    0.912000       125.0
# 1140                    Empagliflozin_Tab 25mg    0.896000       125.0
# 503           CareSens Lancets 0.31mm/30 Gauge    0.895522        67.0
# 1411        Fostair_Inh 200mcg/6mcg (120D) CFF    0.861660       253.0
# 2462   Orbis Nor Saline Sod Chlor 0.9% Nsl Dps    0.858824        85.0
# 3282         Umeclidinium Brom_Inh 65mcg (30D)    0.827586        87.0
# 3279      Ultibro Breezhaler_Pdr Inh Cap + Dev    0.801653       121.0
# 2041                     Medihoney_Barrier Crm    0.784091        88.0
# 1346     Fluoxetine HCl_Oral Soln 20mg/5ml S/F    0.780822        73.0
# 3095                     TEE2 (Reagent)_Strips    0.777778        81.0
# 3430                      Zaluron XL_Tab 400mg    0.758621        58.0
# 1873      Laxido_Paed Plain Oral Pdr Sach 6.9g    0.758621       174.0
# 2641         Prednisolone_Oral Soln 5mg/5ml Ud    0.726027        73.0
# 416        Buprenorphine_Patch 15mcg/hr (7day)    0.715596       109.0
# 795   Coloplast_SenSura Mio Maxi Drnbl Bag S/C    0.703704        81.0
# 2382           Octenisan_Antimicrobial Wsh Lot    0.702703        74.0
# 1076        Duaklir Genuair_340mcg/12mcg (60D)    0.671053       152.0
# 2992      Sod Chlor_Inh Soln 0.9% 2.5ml Ud Amp    0.641975       162.0
# 794   Coloplast_SenSura Mio Maxi Drnbl Bag L/C    0.627451        51.0
# 1375            Flutiform_Inha 50/5mcg (120 D)    0.625000        88.0
# 1688           Ins Degludec_100u/ml 3ml Pf Pen    0.616667        60.0
# 504           CareSens Lancets 0.36mm/28 Gauge    0.611111        90.0
# 1177                           Epimax Crm 500g    0.610000       100.0
# 1243             Evacal D3_Tab Chble 400u/1.5g    0.604651        86.0
# 2946                          Shortec_Cap 20mg    0.602941        68.0
# 717   Co-Trimoxazole_Oral Susp 40/200mg/5mlS/F    0.600000        50.0
# 595      Ciprofloxacin_Gran For Susp 250mg/5ml    0.592105        76.0
# 71    AgaMatrix Ultra-Thin Lancets 0.35mm/28 G    0.566038        53.0
# 3436                  Zemtard 120 XL_Cap 120mg    0.563636        55.0
# 2370                    Nutramigen 2 + LGG_Pdr    0.560440        91.0
# 3210      Toujeo_300u/ml 1.5ml Pf SoloStar Pen    0.540881       159.0
# 1722  Ins Tresiba_FlexTouch 100u/ml 3ml Pf Pen    0.540541       148.0
# 1954                      Longtec_Tab 30mg M/R    0.537037       108.0
# 44                              Adalat_Cap 5mg    0.536585        82.0
# 953             Dexameth_Oral Soln 2mg/5ml S/F    0.529412        68.0
# 1574            Haloperidol_Inj 5mg/ml 1ml Amp    0.528846       104.0
# 1989                     Lyclear_Dermal Crm 5%    0.521127        71.0
# 3334        Valupak_Multivit & Mineral Tab OAD    0.509804        51.0
# 800   Coloplast_Sensura Mio Maxi Clsd Bag + Fl    0.505618        89.0
# 2042                     Medikinet XL_Cap 10mg    0.484848        99.0
# 1056                        Dovobet_Gel Applic    0.481481        54.0
# 1674           Incruse Ellipta_Inh 55mcg (30D)    0.480769       208.0

# %%
df_script_growth.tail(50)
# Out:
#                                       bnf_name  pct_growth  raw_counts
# 2505                Oxycodone HCl_Tab 20mg M/R   -0.431818       264.0
# 499                         Cardura XL_Tab 4mg   -0.434783        69.0
# 2510                Oxycodone HCl_Tab 80mg M/R   -0.435897        78.0
# 3364               Verapamil HCl_Cap 120mg M/R   -0.437908       153.0
# 3199                         Topamax_Tab 100mg   -0.451613        62.0
# 2448               Opticrom_Allergy Eye Dps 2%   -0.452381       126.0
# 2455                    Optilast_Eye Dps 0.05%   -0.454545        55.0
# 37                Actonel_Once a Week Tab 35mg   -0.457627        59.0
# 2665                  Premique_Tab 0.625mg/5mg   -0.470395       304.0
# 3072           Sunsense_Daily Face Crm Spf 50+   -0.483444       151.0
# 1602        Hydrocort/Crotamiton_Crm 0.25%/10%   -0.489362       141.0
# 257            Azelastine HCl_Aq Eye Dps 0.05%   -0.503623       276.0
# 2449                  Opticrom_Eye Dps 2% (Aq)   -0.507389       203.0
# 2134             Metoprolol Tart_Tab 200mg M/R   -0.509091        55.0
# 2779                        Rapitil_Eye Dps 2%   -0.509677       155.0
# 937      Desloratadine_Oral Soln 2.5mg/5ml S/F   -0.514706       136.0
# 1195           Erythromycin_Ethylsuc Tab 500mg   -0.515464        97.0
# 177   Aquacel Foam Adhesive 8cm x 8cm Wound Dr   -0.529412        68.0
# 3458                   Zirtek_Allergy Tab 10mg   -0.530303        66.0
# 152      Antaz Sulf/Xylomet_Eye Dps 0.5%/0.05%   -0.545455        66.0
# 3396               Vital 1.5kcal_Liq (Vanilla)   -0.546667        75.0
# 2488    Oxybutynin HCl_Oral Soln 2.5mg/5ml S/F   -0.557377        61.0
# 2634                   Prazosin HCl_Tab 500mcg   -0.558140        86.0
# 194                 Artificial Saliva_Spy 50ml   -0.558685       213.0
# 3074                Sunsense_Ultra Lot Spf 50+   -0.565217       368.0
# 3132                     Telfast 120_Tab 120mg   -0.569892        93.0
# 2468                 Otrivine-Antistin_Eye Dps   -0.572464       138.0
# 1305                 Fexofenadine HCl_Tab 30mg   -0.595960       297.0
# 2016                            Mag Trisil_Mix   -0.611940        67.0
# 1480                     Glibenclamide_Tab 5mg   -0.616438       146.0
# 710               Co-Danthrusate_Cap 50mg/60mg   -0.629630        81.0
# 1832         Ketotifen Fumar_Eye Dps 250mcg/ml   -0.684211        57.0
# 3317                    Uvistat_Sun Crm Spf 50   -0.691729       133.0
# 1571                  Haelan_Tape 7.5cm x 50cm   -0.713043       115.0
# 1570                  Haelan_Tape 7.5cm x 20cm   -0.720000       100.0
# 307    Beconase_Hayfever Nsl Spy 50mcg (180 D)   -0.738462        65.0
# 3316                    Uvistat_Sun Crm Spf 30   -0.764706        68.0
# 912                    Deep Freeze_Cold Gel 2%   -0.775862        58.0
# 60                         Adizem-SR_Tab 120mg   -0.826923        52.0
# 153                            Anugesic HC_Crm   -0.854167        96.0
# 3073         Sunsense_Sunsensitive Crm SPF 50+   -0.856209       153.0
# 1584      Hepatyrix_Vac 1440u/25mcg/ml 1ml Pfs   -0.875000       216.0
# 624                          Climagest_Tab 2mg   -0.893939        66.0
# 626                           Climaval_Tab 2mg   -0.901515       132.0
# 2464                 Orphenadrine HCl_Tab 50mg   -0.911765       102.0
# 1623        Hydroxyzine HCl_Oral Soln 10mg/5ml   -0.914894        94.0
# 2471                               Ovysmen_Tab   -0.925373        67.0
# 625                           Climaval_Tab 1mg   -0.926471       136.0
# 627                               Climesse_Tab   -0.942029        69.0
# 2613                      Polyalc_Eye Dps 1.4%   -0.996324       272.0

# %%
#return the 50 items with largest growth and the 50 items with the largest shrinkage (i.e. negative percent growth) 
#as a list of tuples sorted by growth rate in descending order in the format (script_name, growth_rate, raw_2016_count)

#using pd.concat to join the top 50 and and last 50 together

df_script_growth_1= df_script_growth.head(50)
df_script_growth_2= df_script_growth.tail(50)
total_script_growth= [df_script_growth_1, df_script_growth_2]
script_growth=pd.concat(total_script_growth)

script_growth
# Out:
#                                       bnf_name  pct_growth  raw_counts
# 431            Butec_Transdermal Patch 5mcg/hr    3.467742        62.0
# 430           Butec_Transdermal Patch 10mcg/hr    3.000000        69.0
# 1409  Fostair NEXThaler_Inh 200mcg/6mcg (120D)    1.430233        86.0
# 2612     Pneumococcal_Vac 0.5ml Vl (23 Valent)    1.269430       193.0
# 3033  Spiolto Respimat_Inha2.5/2.5mcg(60D)+Dev    1.269231        52.0
# ...                                        ...         ...         ...
# 1623        Hydroxyzine HCl_Oral Soln 10mg/5ml   -0.914894        94.0
# 2471                               Ovysmen_Tab   -0.925373        67.0
# 625                           Climaval_Tab 1mg   -0.926471       136.0
# 627                               Climesse_Tab   -0.942029        69.0
# 2613                      Polyalc_Eye Dps 1.4%   -0.996324       272.0
#
# [100 rows x 3 columns]

# %%
#script_growth = [("Butec_Transdermal Patch 5mcg\/hr", 3.4677419355, 62.0)] * 100

# %%
grader.score.dw__script_growth(script_growth)
# Out:
# ==================
# Your score:  1.0
# ==================

# %% [markdown]
# ## Question 6: rare_scripts
#
# Does a practice's prescription costs originate from routine care or from reliance on rarely prescribed treatments? Commonplace treatments can carry lower costs than rare treatments because of efficiencies in large-scale production. While some specialist practices can't help but avoid prescribing rare medicines because there are no alternatives, some practices may be prescribing a unnecessary amount of brand-name products when generics are available. Let's identify practices whose costs disproportionately originate from rarely prescribed items.
#
# First we have to identify which `'bnf_code'` are rare. To do this, find the probability $p$ of a prescription having a particular `'bnf_code'` if the `'bnf_code'` was randomly chosen from the unique options in the beneficiary data. We will call a `'bnf_code'` rare if it is prescribed at a rate less than $0.1p$.

# %%
scripts['bnf_code'].nunique()
# Out:
# 1975

# %%
#or
len(scripts['bnf_code'].unique())
# Out:
# 1975

# %%
1/scripts['bnf_code'].nunique()
# Out:
# 0.0005063291139240507

# %%
scripts['bnf_code'].value_counts()
# Out:
# 0906040G0    14442
# 090402000    10721
# 0302000N0     9940
# 130201000     8602
# 0601060D0     8563
#              ...
# 237541075        1
# 200502005        1
# 0205010AB        1
# 0501022B0        1
# 090602400        1
# Name: bnf_code, Length: 1975, dtype: int64

# %%
scripts.shape[0]
# Out:
# 973193

# %%
len(scripts)
# Out:
# 973193

# %%
#Callin a rare drug/prescription one in which its frequency is less than 01*p

# %%
p = 1/scripts['bnf_code'].nunique()
rates = scripts['bnf_code'].value_counts()/scripts.shape[0]
rare_codes = rates < (0.1 * p)
scripts=(scripts
        .set_index('bnf_code')
        .assign(rare=rare_codes)
        .reset_index())
#scripts['rare'] = rare_codes

# %%
#rare_codes

# %%
scripts.head()
# Out:
#     bnf_code practice                              bnf_name  items   nic  \
# 0  0106020C0   N85639                 Bisacodyl_Tab E/C 5mg      1  0.39
# 1  0106040M0   N85639      Movicol Plain_Paed Pdr Sach 6.9g      1  4.38
# 2  0301011R0   N85639    Salbutamol_Inha 100mcg (200 D) CFF      1  1.50
# 3  0304010G0   N85639  Chlorphenamine Mal_Oral Soln 2mg/5ml      1  2.62
# 4  0401020K0   N85639                      Diazepam_Tab 2mg      1  0.16
#
#    act_cost  quantity   rare
# 0      0.47        12  False
# 1      4.07        30  False
# 2      1.40         1  False
# 3      2.44       150  False
# 4      0.26         6  False

# %% [markdown]
# Now for each practice, calculate the proportion of costs that originate from prescription of rare treatments (i.e. rare `'bnf_code'`). Use the `'act_cost'` field for this calculation.

# %%
total_rare_cost=(scripts
                .query('rare==True')
                .groupby('practice')['act_cost']
                .sum())

# %%
total_rare_cost
# Out:
# practice
# A81005    1247.83
# A81007     951.06
# A81011     816.02
# A81012    1145.11
# A81017    1712.15
#            ...
# Y05434    5918.27
# Y05435    2428.19
# Y05438     762.02
# Y05493      40.89
# Y05660       2.83
# Name: act_cost, Length: 766, dtype: float64

# %%
total_cost=scripts.groupby('practice')['act_cost'].sum()

# %%
total_cost
# Out:
# practice
# A81005    103840.82
# A81007    113482.49
# A81011    159507.03
# A81012     83296.81
# A81017    232656.17
#             ...
# Y05570        86.76
# Y05583      1610.16
# Y05597        90.41
# Y05660      8762.51
# Y05670        36.95
# Name: act_cost, Length: 856, dtype: float64

# %%
total_rare_cost/total_cost
# Out:
# practice
# A81005    0.012017
# A81007    0.008381
# A81011    0.005116
# A81012    0.013747
# A81017    0.007359
#             ...
# Y05570         NaN
# Y05583         NaN
# Y05597         NaN
# Y05660    0.000323
# Y05670         NaN
# Name: act_cost, Length: 856, dtype: float64

# %%
#using fillna(0) to remove the NaN with 0
rare_cost_prop = (total_rare_cost/total_cost).fillna(0,)

# %%
rare_cost_prop
# Out:
# practice
# A81005    0.012017
# A81007    0.008381
# A81011    0.005116
# A81012    0.013747
# A81017    0.007359
#             ...
# Y05570    0.000000
# Y05583    0.000000
# Y05597    0.000000
# Y05660    0.000323
# Y05670    0.000000
# Name: act_cost, Length: 856, dtype: float64

# %% [markdown]
# Now we will calculate a z-score for each practice based on this proportion.
# First take the difference of `rare_cost_prop` and the proportion of costs originating from rare treatments across all practices.

# %%
relative_rare_cost_prop =(rare_cost_prop-scripts.query('rare ==True')['act_cost'].sum()/scripts['act_cost'].sum())

# %%
relative_rare_cost_prop
# Out:
# practice
# A81005   -0.003946
# A81007   -0.007582
# A81011   -0.010847
# A81012   -0.002216
# A81017   -0.008604
#             ...
# Y05570   -0.015963
# Y05583   -0.015963
# Y05597   -0.015963
# Y05660   -0.015640
# Y05670   -0.015963
# Name: act_cost, Length: 856, dtype: float64

# %% [markdown]
# Now we will estimate the standard errors (i.e. the denominator of the z-score) by simply taking the standard deviation of this difference.

# %%
standard_errors= relative_rare_cost_prop.std()

# %%
standard_errors
# Out:
# 0.06050888706745139

# %% [markdown]
# Finally compute the z-scores. Return the practices with the top 100 z-scores in the form `(post_code, practice_name, z-score)`. Note that some practice codes will correspond with multiple names. In this case, use the first match when sorting names alphabetically.

# %%
rare_scores= (relative_rare_cost_prop/ standard_errors).rename('rare_score')

# %%
rare_scores
# Out:
# practice
# A81005   -0.065216
# A81007   -0.125308
# A81011   -0.179263
# A81012   -0.036615
# A81017   -0.142190
#             ...
# Y05570   -0.263811
# Y05583   -0.263811
# Y05597   -0.263811
# Y05660   -0.258473
# Y05670   -0.263811
# Name: rare_score, Length: 856, dtype: float64

# %%
result=practice_unique.merge(rare_scores, left_on='code', right_index=True)

# %%
result= (practice_unique
         .set_index('code')
         .assign(rare_score=rare_scores)
         .reset_index())

# %%
result=result[['code', 'name', 'rare_score']]
result
# Out:
#          code                               name  rare_score
# 0      E82060             PARKBURY HOUSE SURGERY         NaN
# 1      E82031                   MALTINGS SURGERY         NaN
# 2      E82004              HATFIELD ROAD SURGERY         NaN
# 3      E82002              WRAFTON HOUSE SURGERY         NaN
# 4      Y05146  HCT LYMPHOEDEMA AT WEST ESSEX CCG         NaN
# ...       ...                                ...         ...
# 10838  Y04010           SOUTH YORK COMM SERV (1)         NaN
# 10839  Y04012           SOUTH YORK COMM SERV (3)         NaN
# 10840  B82041                 BEECH TREE SURGERY         NaN
# 10841  Y04011           SOUTH YORK COMM SERV (2)         NaN
# 10842  Y00217                          SELBY MIU         NaN
#
# [10843 rows x 3 columns]

# %%
f_result=(result[['code', 'name', 'rare_score']]
          .sort_values('rare_score', ascending=False)
          )

# %%
f_result.head(100)
# Out:
#          code                               name  rare_score
# 6824   Y03472           CONSULTANT DIABETES TEAM   16.262687
# 327    Y05320     DMC COMMUNITY DERMATOLOGY RBWF   15.128648
# 8392   Y04404  OUTPATIENTS JUBILEE HEALTH CENTRE    7.542139
# 5424   Y03484   DMC COMMUNITY DERMATOLOGY CLINIC    7.287222
# 8794   Y04424                     DMC HEALTHCARE    6.838614
# ...       ...                                ...         ...
# 9790   Y02671     THE PRACTICE HEART OF HOUNSLOW    0.208809
# 3113   F84631                       DR PI ABIOLA    0.205391
# 2728   B81012                        DR AP KUMAR    0.203691
# 4854   C83613              CAISTOR HEALTH CENTRE    0.203500
# 10583  M91614                    STROUD PRACTICE    0.200505
#
# [100 rows x 3 columns]

# %%
#result['rare_score'].isna().sum()
# Out:
# 9987

# %%
#result.shape
# Out:
# (10843, 3)

# %%
rare_scripts=f_result.head(100)

# %%
rare_scripts = [("Y03472", "CONSULTANT DIABETES TEAM", 16.2626871247)] * 100

# %%
grader.score.dw__rare_scripts(rare_scripts)
# Out:
# ==================
# Your score:  0.9500000000000006
# ==================

# %% [markdown]
# *Copyright &copy; 2020 The Data Incubator.  All rights reserved.*
